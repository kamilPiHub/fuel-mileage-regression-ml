# %% [markdown]
# # Przewidywanie zuzycia paliwa w pojazdach (regresja)
# ---
#
# **Cel projektu:** Przewidzenie zuzycia paliwa w pojazdach na podstawie cech technicznych (moc, masa, liczba cylindrow).
#
# **Zbior danych:** UCI Auto MPG Dataset
# **Link:** https://raw.githubusercontent.com/mwaskom/seaborn-data/master/mpg.csv
#
# **Algorytmy porownawcze:**
# - MLPRegressor - scikit-learn
# - RandomForestRegressor - scikit-learn
# - SVR - scikit-learn
# - KNeighborsRegressor - scikit-learn
# - Deep Neural Network - TensorFlow/Keras (GPU)
#
# **Biblioteki:** pandas, seaborn, matplotlib, scikit-learn, tensorflow
#
# **Metodologia:**
# - Optymalizacja hiperparametrow: GridSearchCV (MLP, Random Forest)
# - Bledy wzgledne (MAPE)
# - Dokladnosc w zaleznosci od typu samochodu
# - Wykresy porownawcze
#
# ---

# %% [markdown]
# ## 1. Import bibliotek

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('husl')
plt.rcParams['figure.figsize'] = (12, 6)

print('Wersje bibliotek:')
print(f'NumPy: {np.__version__}')
print(f'Pandas: {pd.__version__}')
print(f'Scikit-learn: {__import__("sklearn").__version__}')
print(f'TensorFlow: {tf.__version__}')
print(f'Dostepnosc GPU: {len(tf.config.list_physical_devices("GPU")) > 0}')
# Out:
# Wersje bibliotek:
# NumPy: 2.0.2
# Pandas: 2.2.2
# Scikit-learn: 1.6.1
# TensorFlow: 2.20.0
# Dostepnosc GPU: True

# %% [markdown]
# ## 2. Ladowanie i eksploracja zbioru danych

# %%
url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/mpg.csv'
df = pd.read_csv(url)

print('PODSTAWOWE INFORMACJE O ZBIORZE DANYCH')
print(f'Liczba rekordow: {df.shape[0]}')
print(f'Liczba atrybutow: {df.shape[1]}')
print(f'\nBrakujace wartosci:')
print(df.isnull().sum())

print('\nPIERWSZYCH 5 REKORDOW:')
display(df.head())

print('\nSTATYSTYKI OPISOWE:')
display(df.describe())
# Out:
# PODSTAWOWE INFORMACJE O ZBIORZE DANYCH
# Liczba rekordow: 398
# Liczba atrybutow: 9
#
# Brakujace wartosci:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64
#
# PIERWSZYCH 5 REKORDOW:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino
# STATYSTYKI OPISOWE:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %% [markdown]
# ## 3. Rozklady cech i macierz korelacji

# %%
fig, axes = plt.subplots(2, 4, figsize=(16, 10))
fig.suptitle('Rozklady cech numerycznych', fontsize=14, fontweight='bold')

numeric_cols = ['mpg', 'cylinders', 'displacement', 'horsepower',
                'weight', 'acceleration', 'model_year']

for idx, col in enumerate(numeric_cols):
    ax = axes[idx // 4, idx % 4]
    sns.histplot(df[col].dropna(), kde=True, ax=ax, bins=20)
    ax.set_title(f'Rozklad: {col}')
    ax.set_xlabel('')

plt.tight_layout()
plt.show()

print('\nRozklad atrybutu origin (kraj pochodzenia):')
print(df['origin'].value_counts().sort_index())
# Out:
# Rozklad atrybutu origin (kraj pochodzenia):
# origin
# europe     70
# japan      79
# usa       249
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 10))
correlation_matrix = df[numeric_cols].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='RdBu_r', center=0,
            fmt='.3f', square=True, linewidths=0.5)
plt.title('Macierz korelacji', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

print('\nKorelacje z mpg:')
print(correlation_matrix['mpg'].sort_values(ascending=False))
# Out:
# Korelacje z mpg:
# mpg             1.000000
# model_year      0.579267
# acceleration    0.420289
# cylinders      -0.775396
# horsepower     -0.778427
# displacement   -0.804203
# weight         -0.831741
# Name: mpg, dtype: float64

# %% [markdown]
# ## 4. Przetwarzanie wstepne danych

# %%
df_clean = df.copy()

print(f'Rekordy z NaN: {df_clean.isnull().sum().sum()}')
df_clean = df_clean.dropna()
print(f'Rekordy po usunieciu NaN: {len(df_clean)}')

def extract_car_type(name):
    name_lower = str(name).lower()
    if any(x in name_lower for x in ['ford', 'chevrolet', 'plymouth', 'dodge', 'amc', 'buick', 'chrysler', 'pontiac', 'oldsmobile', 'mercury', 'cadillac', 'lincoln']):
        return 'amerykanski'
    elif any(x in name_lower for x in ['vw', 'volkswagen', 'bmw', 'audi', 'opel', 'peugeot', 'renault', 'volvo', 'saab', 'fiat']):
        return 'europejski'
    elif any(x in name_lower for x in ['toyota', 'honda', 'datsun', 'mazda', 'subaru', 'nissan', 'mitsubishi']):
        return 'japonski'
    else:
        return 'inny'

df_clean['car_type'] = df_clean['name'].apply(extract_car_type)

print('\nRozklad typow pojazdow:')
print(df_clean['car_type'].value_counts())

df_clean['origin'] = df_clean['origin'].astype(str)
origin_dummies = pd.get_dummies(df_clean['origin'], prefix='origin', dtype=int)
df_processed = pd.concat([df_clean, origin_dummies], axis=1)

origin_cols = [col for col in df_processed.columns if col.startswith('origin_')]
feature_columns = ['cylinders', 'displacement', 'horsepower', 'weight',
                   'acceleration', 'model_year'] + origin_cols

X = df_processed[feature_columns].values
y = df_processed['mpg'].values
car_types_all = df_processed['car_type'].values

X_train, X_test, y_train, y_test, car_type_train, car_type_test = train_test_split(
    X, y, car_types_all, test_size=0.2, random_state=42
)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print(f'\nX_train: {X_train_scaled.shape}, X_test: {X_test_scaled.shape}')
# Out:
# Rekordy z NaN: 6
# Rekordy po usunieciu NaN: 392
#
# Rozklad typow pojazdow:
# car_type
# amerykanski    239
# japonski        76
# europejski      63
# inny            14
# Name: count, dtype: int64
#
# X_train: (313, 9), X_test: (79, 9)

# %% [markdown]
# ## 5. Definicja metryk jakosci

# %%
def calculate_metrics(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    return {'MAE': mae, 'MSE': mse, 'RMSE': rmse, 'R2': r2, 'MAPE': mape}

results = {}
predictions = {}

# %% [markdown]
# ## 6. MLPRegressor - optymalizacja GridSearchCV

# %%
print('OPTYMALIZACJA - MLPRegressor (GridSearchCV)')

mlp_param_grid = {
    'hidden_layer_sizes': [(50,), (100,), (50, 50), (100, 50)],
    'activation': ['relu', 'tanh'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate_init': [0.001, 0.01]
}

mlp_base = MLPRegressor(max_iter=1000, random_state=42, early_stopping=True)

mlp_grid = GridSearchCV(
    estimator=mlp_base,
    param_grid=mlp_param_grid,
    cv=5,
    scoring='neg_mean_squared_error',
    n_jobs=-1,
    verbose=1
)

mlp_grid.fit(X_train_scaled, y_train)

print(f'\nNajlepsze parametry:')
for param, value in mlp_grid.best_params_.items():
    print(f'  {param}: {value}')

mlp_best = mlp_grid.best_estimator_
y_pred_mlp = mlp_best.predict(X_test_scaled)
results['MLPRegressor'] = calculate_metrics(y_test, y_pred_mlp)
predictions['MLPRegressor'] = y_pred_mlp

print(f'\nMetryki testowe:')
for metric, value in results['MLPRegressor'].items():
    print(f'  {metric}: {value:.4f}')
# Out:
# OPTYMALIZACJA - MLPRegressor (GridSearchCV)
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
#
# Najlepsze parametry:
#   activation: relu
#   alpha: 0.01
#   hidden_layer_sizes: (100,)
#   learning_rate_init: 0.01
#
# Metryki testowe:
#   MAE: 1.9120
#   MSE: 8.0533
#   RMSE: 2.8378
#   R2: 0.8422
#   MAPE: 8.2820

# %% [markdown]
# ## 7. RandomForestRegressor - optymalizacja GridSearchCV

# %%
print('OPTYMALIZACJA - RandomForestRegressor (GridSearchCV)')

rf_param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

rf_base = RandomForestRegressor(random_state=42)

rf_grid = GridSearchCV(
    estimator=rf_base,
    param_grid=rf_param_grid,
    cv=5,
    scoring='neg_mean_squared_error',
    n_jobs=-1,
    verbose=1
)

rf_grid.fit(X_train, y_train)

print(f'\nNajlepsze parametry:')
for param, value in rf_grid.best_params_.items():
    print(f'  {param}: {value}')

rf_best = rf_grid.best_estimator_
y_pred_rf = rf_best.predict(X_test)
results['RandomForest'] = calculate_metrics(y_test, y_pred_rf)
predictions['RandomForest'] = y_pred_rf

print(f'\nMetryki testowe:')
for metric, value in results['RandomForest'].items():
    print(f'  {metric}: {value:.4f}')

print('\nWaznosc cech (Random Forest):')
feature_importance = pd.DataFrame({
    'Cecha': feature_columns,
    'Waznosc': rf_best.feature_importances_
}).sort_values('Waznosc', ascending=False)
print(feature_importance.to_string(index=False))
# Out:
# OPTYMALIZACJA - RandomForestRegressor (GridSearchCV)
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
#
# Najlepsze parametry:
#   max_depth: None
#   min_samples_leaf: 1
#   min_samples_split: 5
#   n_estimators: 300
#
# Metryki testowe:
#   MAE: 1.6741
#   MSE: 5.6382
#   RMSE: 2.3745
#   R2: 0.8895
#   MAPE: 7.6276
#
# Waznosc cech (Random Forest):
#         Cecha  Waznosc
#  displacement 0.423417
#    horsepower 0.169948
#        weight 0.141534
#     cylinders 0.135740
#    model_year 0.102132
#  acceleration 0.021739
#  origin_japan 0.002367
# origin_europe 0.001859
#    origin_usa 0.001266

# %% [markdown]
# ## 8. SVR i KNeighborsRegressor

# %%
print('TRENOVANIE - SVR')

svr_model = SVR(kernel='rbf', C=10, epsilon=0.1, gamma='scale')
svr_model.fit(X_train_scaled, y_train)

y_pred_svr = svr_model.predict(X_test_scaled)
results['SVR'] = calculate_metrics(y_test, y_pred_svr)
predictions['SVR'] = y_pred_svr

print(f'Metryki testowe:')
for metric, value in results['SVR'].items():
    print(f'  {metric}: {value:.4f}')

print('\nTRENOVANIE - KNeighborsRegressor')

knn_model = KNeighborsRegressor(n_neighbors=5, weights='distance')
knn_model.fit(X_train_scaled, y_train)

y_pred_knn = knn_model.predict(X_test_scaled)
results['KNeighbors'] = calculate_metrics(y_test, y_pred_knn)
predictions['KNeighbors'] = y_pred_knn

print(f'Metryki testowe:')
for metric, value in results['KNeighbors'].items():
    print(f'  {metric}: {value:.4f}')
# Out:
# TRENOVANIE - SVR
# Metryki testowe:
#   MAE: 1.7669
#   MSE: 5.9679
#   RMSE: 2.4429
#   R2: 0.8831
#   MAPE: 7.6962
#
# TRENOVANIE - KNeighborsRegressor
# Metryki testowe:
#   MAE: 1.9459
#   MSE: 6.7440
#   RMSE: 2.5969
#   R2: 0.8679
#   MAPE: 8.6969

# %% [markdown]
# ## 9. TensorFlow Deep Neural Network (GPU)

# %%
print('TRENOWANIE - TensorFlow DNN (GPU)')
print(f'GPU: {tf.config.list_physical_devices("GPU")}')

early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=20, restore_best_weights=True
)

reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=10, min_lr=1e-6
)

tf_model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    layers.BatchNormalization(),
    layers.Dropout(0.2),
    layers.Dense(64, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.2),
    layers.Dense(32, activation='relu'),
    layers.Dense(1)
])

tf_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae']
)

tf_model.summary()

history = tf_model.fit(
    X_train_scaled, y_train,
    validation_split=0.2,
    epochs=200,
    batch_size=32,
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)

y_pred_tf = tf_model.predict(X_test_scaled).flatten()
results['TensorFlow_DNN'] = calculate_metrics(y_test, y_pred_tf)
predictions['TensorFlow_DNN'] = y_pred_tf

print(f'\nMetryki testowe:')
for metric, value in results['TensorFlow_DNN'].items():
    print(f'  {metric}: {value:.4f}')
# Out:
# TRENOWANIE - TensorFlow DNN (GPU)
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         1,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,417 (48.50 KB)
#  Trainable params: 12,033 (47.00 KB)
#  Non-trainable params: 384 (1.50 KB)
# Epoch 1/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 405ms/step - loss: 553.1439 - mae: 22.2487 - val_loss: 660.7473 - val_mae: 24.5518 - learning_rate: 0.0010
# Epoch 2/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 499.6354 - mae: 21.3719 - val_loss: 641.9851 - val_mae: 24.2255 - learning_rate: 0.0010
# Epoch 3/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 444.2682 - mae: 20.2691 - val_loss: 616.2602 - val_mae: 23.7634 - learning_rate: 0.0010
# Epoch 4/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 403.5486 - mae: 19.3143 - val_loss: 584.0874 - val_mae: 23.1702 - learning_rate: 0.0010
# Epoch 5/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 358.5410 - mae: 18.1615 - val_loss: 546.7675 - val_mae: 22.4600 - learning_rate: 0.0010
# Epoch 6/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 307.4129 - mae: 16.8910 - val_loss: 503.0564 - val_mae: 21.5947 - learning_rate: 0.0010
# Epoch 7/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 262.2068 - mae: 15.4220 - val_loss: 454.6781 - val_mae: 20.5837 - learning_rate: 0.0010
# Epoch 8/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 218.2782 - mae: 13.9095 - val_loss: 406.5789 - val_mae: 19.5006 - learning_rate: 0.0010
# Epoch 9/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 172.3634 - mae: 12.2593 - val_loss: 356.1829 - val_mae: 18.2826 - learning_rate: 0.0010
# Epoch 10/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 136.8494 - mae: 10.3534 - val_loss: 309.9681 - val_mae: 17.0571 - learning_rate: 0.0010
# Epoch 11/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 123.3256 - mae: 9.4779 - val_loss: 268.2188 - val_mae: 15.8365 - learning_rate: 0.0010
# Epoch 12/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 101.6499 - mae: 8.2125 - val_loss: 235.2581 - val_mae: 14.7638 - learning_rate: 0.0010
# Epoch 13/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 94.4717 - mae: 8.0205 - val_loss: 208.6699 - val_mae: 13.8255 - learning_rate: 0.0010
# Epoch 14/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 74.0295 - mae: 6.8895 - val_loss: 189.7413 - val_mae: 13.1314 - learning_rate: 0.0010
# Epoch 15/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 64.5701 - mae: 6.3330 - val_loss: 172.4573 - val_mae: 12.4763 - learning_rate: 0.0010
# Epoch 16/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 58.5968 - mae: 6.0222 - val_loss: 160.7108 - val_mae: 11.9987 - learning_rate: 0.0010
# Epoch 17/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 61.5690 - mae: 6.4390 - val_loss: 153.2481 - val_mae: 11.6804 - learning_rate: 0.0010
# Epoch 18/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 45.8362 - mae: 5.4404 - val_loss: 134.0000 - val_mae: 10.8647 - learning_rate: 0.0010
# Epoch 19/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 47.8654 - mae: 5.5827 - val_loss: 122.4547 - val_mae: 10.3379 - learning_rate: 0.0010
# Epoch 20/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 40.2589 - mae: 5.0935 - val_loss: 112.0603 - val_mae: 9.8623 - learning_rate: 0.0010
# Epoch 21/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 26.7398 - mae: 4.0145 - val_loss: 103.8619 - val_mae: 9.4916 - learning_rate: 0.0010
# Epoch 22/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 31.1312 - mae: 4.3638 - val_loss: 95.6176 - val_mae: 9.0890 - learning_rate: 0.0010
# Epoch 23/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 29.3617 - mae: 4.2288 - val_loss: 87.0175 - val_mae: 8.6323 - learning_rate: 0.0010
# Epoch 24/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 34.0511 - mae: 4.5673 - val_loss: 79.1106 - val_mae: 8.1813 - learning_rate: 0.0010
# Epoch 25/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 26.7529 - mae: 4.0583 - val_loss: 71.6119 - val_mae: 7.7290 - learning_rate: 0.0010
# Epoch 26/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 27.2502 - mae: 4.0820 - val_loss: 66.2506 - val_mae: 7.4039 - learning_rate: 0.0010
# Epoch 27/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 21.1934 - mae: 3.5257 - val_loss: 61.6369 - val_mae: 7.1268 - learning_rate: 0.0010
# Epoch 28/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 26.7339 - mae: 3.8860 - val_loss: 57.9997 - val_mae: 6.8782 - learning_rate: 0.0010
# Epoch 29/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 21.4977 - mae: 3.5878 - val_loss: 54.1415 - val_mae: 6.5979 - learning_rate: 0.0010
# Epoch 30/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 16.6513 - mae: 3.1018 - val_loss: 48.7638 - val_mae: 6.2380 - learning_rate: 0.0010
# Epoch 31/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 21.7984 - mae: 3.6688 - val_loss: 43.6816 - val_mae: 5.8781 - learning_rate: 0.0010
# Epoch 32/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 18.2606 - mae: 3.2857 - val_loss: 40.3401 - val_mae: 5.6164 - learning_rate: 0.0010
# Epoch 33/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 21.1951 - mae: 3.5396 - val_loss: 39.8072 - val_mae: 5.5677 - learning_rate: 0.0010
# Epoch 34/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 24.7164 - mae: 3.8459 - val_loss: 38.6588 - val_mae: 5.4662 - learning_rate: 0.0010
# Epoch 35/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 27.6777 - mae: 4.1951 - val_loss: 38.5588 - val_mae: 5.4362 - learning_rate: 0.0010
# Epoch 36/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 21.6217 - mae: 3.5769 - val_loss: 33.4248 - val_mae: 5.0023 - learning_rate: 0.0010
# Epoch 37/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 16.9496 - mae: 3.1580 - val_loss: 28.6746 - val_mae: 4.5692 - learning_rate: 0.0010
# Epoch 38/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 20.3571 - mae: 3.5303 - val_loss: 28.0178 - val_mae: 4.5212 - learning_rate: 0.0010
# Epoch 39/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 18.6267 - mae: 3.3250 - val_loss: 25.5269 - val_mae: 4.2874 - learning_rate: 0.0010
# Epoch 40/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 26.9408 - mae: 3.9308 - val_loss: 24.7827 - val_mae: 4.2195 - learning_rate: 0.0010
# Epoch 41/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 21.6216 - mae: 3.5240 - val_loss: 23.5812 - val_mae: 4.0795 - learning_rate: 0.0010
# Epoch 42/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 22.8967 - mae: 3.5035 - val_loss: 23.7835 - val_mae: 4.0897 - learning_rate: 0.0010
# Epoch 43/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 14.5567 - mae: 2.8576 - val_loss: 20.5494 - val_mae: 3.7385 - learning_rate: 0.0010
# Epoch 44/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 21.3753 - mae: 3.5329 - val_loss: 16.9773 - val_mae: 3.2884 - learning_rate: 0.0010
# Epoch 45/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 15.6507 - mae: 3.1019 - val_loss: 17.3669 - val_mae: 3.3377 - learning_rate: 0.0010
# Epoch 46/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 19.0509 - mae: 3.3713 - val_loss: 17.3322 - val_mae: 3.3112 - learning_rate: 0.0010
# Epoch 47/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 19.7502 - mae: 3.4353 - val_loss: 14.8649 - val_mae: 3.0104 - learning_rate: 0.0010
# Epoch 48/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 16.3391 - mae: 3.0894 - val_loss: 15.8001 - val_mae: 3.1025 - learning_rate: 0.0010
# Epoch 49/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 17.9945 - mae: 3.2985 - val_loss: 15.8237 - val_mae: 3.0708 - learning_rate: 0.0010
# Epoch 50/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 16.2542 - mae: 3.1324 - val_loss: 14.4506 - val_mae: 2.8903 - learning_rate: 0.0010
# Epoch 51/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 20.6705 - mae: 3.3746 - val_loss: 12.5116 - val_mae: 2.6146 - learning_rate: 0.0010
# Epoch 52/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 14.5138 - mae: 2.9083 - val_loss: 11.7423 - val_mae: 2.4868 - learning_rate: 0.0010
# Epoch 53/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 13.9976 - mae: 2.9022 - val_loss: 10.7194 - val_mae: 2.3530 - learning_rate: 0.0010
# Epoch 54/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 16.6988 - mae: 3.1437 - val_loss: 10.3277 - val_mae: 2.2717 - learning_rate: 0.0010
# Epoch 55/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 22.9749 - mae: 3.6508 - val_loss: 11.0050 - val_mae: 2.3872 - learning_rate: 0.0010
# Epoch 56/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 15.6955 - mae: 3.0608 - val_loss: 10.8366 - val_mae: 2.3842 - learning_rate: 0.0010
# Epoch 57/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.6764 - mae: 2.8261 - val_loss: 10.5901 - val_mae: 2.3547 - learning_rate: 0.0010
# Epoch 58/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 13.5854 - mae: 2.7732 - val_loss: 10.1001 - val_mae: 2.2825 - learning_rate: 0.0010
# Epoch 59/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 15.7308 - mae: 3.1260 - val_loss: 9.3327 - val_mae: 2.1830 - learning_rate: 0.0010
# Epoch 60/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 14.8504 - mae: 2.9030 - val_loss: 8.8777 - val_mae: 2.1272 - learning_rate: 0.0010
# Epoch 61/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 17.2899 - mae: 3.2414 - val_loss: 9.0665 - val_mae: 2.1830 - learning_rate: 0.0010
# Epoch 62/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 15.3411 - mae: 3.0514 - val_loss: 8.0418 - val_mae: 2.0436 - learning_rate: 0.0010
# Epoch 63/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 24.8694 - mae: 3.7509 - val_loss: 8.3641 - val_mae: 2.0911 - learning_rate: 0.0010
# Epoch 64/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 17.7055 - mae: 3.3027 - val_loss: 8.4117 - val_mae: 2.1119 - learning_rate: 0.0010
# Epoch 65/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 18.3798 - mae: 3.2786 - val_loss: 7.4961 - val_mae: 1.9972 - learning_rate: 0.0010
# Epoch 66/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 15.2555 - mae: 3.0049 - val_loss: 7.5868 - val_mae: 1.9988 - learning_rate: 0.0010
# Epoch 67/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 15.4766 - mae: 2.8391 - val_loss: 7.5755 - val_mae: 1.9946 - learning_rate: 0.0010
# Epoch 68/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 15.7028 - mae: 3.1029 - val_loss: 7.0143 - val_mae: 1.9298 - learning_rate: 0.0010
# Epoch 69/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.9846 - mae: 2.8369 - val_loss: 7.6707 - val_mae: 2.0013 - learning_rate: 0.0010
# Epoch 70/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 20.9759 - mae: 3.5273 - val_loss: 7.5748 - val_mae: 1.9918 - learning_rate: 0.0010
# Epoch 71/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 15.6672 - mae: 3.0086 - val_loss: 7.4619 - val_mae: 1.9711 - learning_rate: 0.0010
# Epoch 72/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 16.4130 - mae: 3.0413 - val_loss: 8.0892 - val_mae: 2.0398 - learning_rate: 0.0010
# Epoch 73/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 18.7519 - mae: 3.3658 - val_loss: 8.4717 - val_mae: 2.1245 - learning_rate: 0.0010
# Epoch 74/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 12.7011 - mae: 2.8340 - val_loss: 6.8366 - val_mae: 1.8840 - learning_rate: 0.0010
# Epoch 75/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 12.8376 - mae: 2.6691 - val_loss: 6.4233 - val_mae: 1.8367 - learning_rate: 0.0010
# Epoch 76/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 15.9978 - mae: 3.0124 - val_loss: 7.1010 - val_mae: 1.9117 - learning_rate: 0.0010
# Epoch 77/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 16.4098 - mae: 3.0604 - val_loss: 6.7665 - val_mae: 1.8846 - learning_rate: 0.0010
# Epoch 78/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 14.7303 - mae: 2.8719 - val_loss: 6.5533 - val_mae: 1.8589 - learning_rate: 0.0010
# Epoch 79/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 15.4756 - mae: 3.0330 - val_loss: 6.6827 - val_mae: 1.8688 - learning_rate: 0.0010
# Epoch 80/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 12.7770 - mae: 2.7583 - val_loss: 6.7489 - val_mae: 1.8641 - learning_rate: 0.0010
# Epoch 81/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 14.0479 - mae: 2.8626 - val_loss: 6.4231 - val_mae: 1.8277 - learning_rate: 0.0010
# Epoch 82/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.6148 - mae: 2.8911 - val_loss: 6.5402 - val_mae: 1.8510 - learning_rate: 0.0010
# Epoch 83/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 12.2278 - mae: 2.5949 - val_loss: 6.6661 - val_mae: 1.8647 - learning_rate: 0.0010
# Epoch 84/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 15.4117 - mae: 3.0691 - val_loss: 7.2392 - val_mae: 1.9240 - learning_rate: 0.0010
# Epoch 85/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 18.4047 - mae: 3.2375 - val_loss: 6.8358 - val_mae: 1.8838 - learning_rate: 0.0010
# Epoch 86/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 23.3707 - mae: 3.6258 - val_loss: 8.0585 - val_mae: 2.0458 - learning_rate: 0.0010
# Epoch 87/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 16.7803 - mae: 3.0233 - val_loss: 6.4996 - val_mae: 1.8468 - learning_rate: 0.0010
# Epoch 88/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 23.0572 - mae: 3.5487 - val_loss: 7.6611 - val_mae: 1.9820 - learning_rate: 0.0010
# Epoch 89/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 17.6058 - mae: 3.1655 - val_loss: 6.7422 - val_mae: 1.8803 - learning_rate: 0.0010
# Epoch 90/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 15.1166 - mae: 2.9814 - val_loss: 6.9455 - val_mae: 1.9242 - learning_rate: 0.0010
# Epoch 91/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 14.4240 - mae: 2.8583 - val_loss: 7.2754 - val_mae: 1.9672 - learning_rate: 0.0010
# Epoch 92/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.5427 - mae: 2.8560 - val_loss: 7.0313 - val_mae: 1.9383 - learning_rate: 5.0000e-04
# Epoch 93/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 19.1908 - mae: 3.4181 - val_loss: 6.5020 - val_mae: 1.8677 - learning_rate: 5.0000e-04
# Epoch 94/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.7116 - mae: 2.8432 - val_loss: 6.6554 - val_mae: 1.8911 - learning_rate: 5.0000e-04
# Epoch 95/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 21.0150 - mae: 3.4328 - val_loss: 6.7162 - val_mae: 1.8860 - learning_rate: 5.0000e-04
# Epoch 96/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 14.0487 - mae: 2.8373 - val_loss: 6.6963 - val_mae: 1.8819 - learning_rate: 5.0000e-04
# Epoch 97/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 11.6170 - mae: 2.5773 - val_loss: 6.4624 - val_mae: 1.8440 - learning_rate: 5.0000e-04
# Epoch 98/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 16.4860 - mae: 3.0902 - val_loss: 6.2055 - val_mae: 1.8013 - learning_rate: 5.0000e-04
# Epoch 99/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 15.3860 - mae: 2.9551 - val_loss: 6.3484 - val_mae: 1.8175 - learning_rate: 5.0000e-04
# Epoch 100/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 15.3578 - mae: 2.9979 - val_loss: 6.6620 - val_mae: 1.8539 - learning_rate: 5.0000e-04
# Epoch 101/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 14.4633 - mae: 2.9237 - val_loss: 6.7990 - val_mae: 1.8649 - learning_rate: 5.0000e-04
# Epoch 102/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 11.3329 - mae: 2.5732 - val_loss: 6.8461 - val_mae: 1.8704 - learning_rate: 5.0000e-04
# Epoch 103/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 15.4531 - mae: 3.0498 - val_loss: 6.6747 - val_mae: 1.8384 - learning_rate: 5.0000e-04
# Epoch 104/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 15.1522 - mae: 3.0462 - val_loss: 6.5896 - val_mae: 1.8321 - learning_rate: 5.0000e-04
# Epoch 105/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 14.9410 - mae: 2.9134 - val_loss: 6.8142 - val_mae: 1.8657 - learning_rate: 5.0000e-04
# Epoch 106/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 16.5368 - mae: 3.1729 - val_loss: 7.1620 - val_mae: 1.9201 - learning_rate: 5.0000e-04
# Epoch 107/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 12.0927 - mae: 2.6677 - val_loss: 7.4027 - val_mae: 1.9485 - learning_rate: 5.0000e-04
# Epoch 108/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 15.6340 - mae: 3.0423 - val_loss: 7.5698 - val_mae: 1.9656 - learning_rate: 5.0000e-04
# Epoch 109/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 17.5598 - mae: 3.1435 - val_loss: 6.9969 - val_mae: 1.8935 - learning_rate: 2.5000e-04
# Epoch 110/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.1430 - mae: 2.8514 - val_loss: 7.0137 - val_mae: 1.8991 - learning_rate: 2.5000e-04
# Epoch 111/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 12.5990 - mae: 2.7525 - val_loss: 6.9830 - val_mae: 1.8956 - learning_rate: 2.5000e-04
# Epoch 112/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 12.7965 - mae: 2.7225 - val_loss: 7.1166 - val_mae: 1.9136 - learning_rate: 2.5000e-04
# Epoch 113/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 10.4784 - mae: 2.4557 - val_loss: 7.0718 - val_mae: 1.9092 - learning_rate: 2.5000e-04
# Epoch 114/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 17.8056 - mae: 3.1386 - val_loss: 7.3579 - val_mae: 1.9435 - learning_rate: 2.5000e-04
# Epoch 115/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 14.5861 - mae: 2.9277 - val_loss: 7.5001 - val_mae: 1.9548 - learning_rate: 2.5000e-04
# Epoch 116/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 12.3850 - mae: 2.7149 - val_loss: 7.5939 - val_mae: 1.9598 - learning_rate: 2.5000e-04
# Epoch 117/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 11.4015 - mae: 2.5873 - val_loss: 7.4981 - val_mae: 1.9471 - learning_rate: 2.5000e-04
# Epoch 118/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 17.3638 - mae: 3.2526 - val_loss: 7.3763 - val_mae: 1.9295 - learning_rate: 2.5000e-04
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 191ms/step
#
# Metryki testowe:
#   MAE: 1.8800
#   MSE: 6.6483
#   RMSE: 2.5784
#   R2: 0.8697
#   MAPE: 8.3662

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(history.history['loss'], label='Treningowa')
axes[0].plot(history.history['val_loss'], label='Walidacyjna')
axes[0].set_title('Strata (MSE)')
axes[0].set_xlabel('Epoka')
axes[0].set_ylabel('MSE')
axes[0].legend()
axes[0].grid(True)

axes[1].plot(history.history['mae'], label='Treningowe')
axes[1].plot(history.history['val_mae'], label='Walidacyjne')
axes[1].set_title('MAE')
axes[1].set_xlabel('Epoka')
axes[1].set_ylabel('MAE')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Porownanie modeli

# %%
results_df = pd.DataFrame(results).T
results_df = results_df[['MAE', 'MSE', 'RMSE', 'R2', 'MAPE']]

print('POROWNANIE MODELI')
display(results_df.style.format('{:.4f}').highlight_min(color='lightgreen'))

print('\nRanking (R2):')
ranking = results_df['R2'].sort_values(ascending=False)
for i, (model, score) in enumerate(ranking.items(), 1):
    print(f'  {i}. {model}: R2 = {score:.4f}')
# Out:
# POROWNANIE MODELI
# <style type="text/css">
# #T_4bba1_row0_col3, #T_4bba1_row1_col0, #T_4bba1_row1_col1, #T_4bba1_row1_col2, #T_4bba1_row1_col4 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4bba1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4bba1_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_4bba1_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_4bba1_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_4bba1_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_4bba1_level0_col4" class="col_heading level0 col4" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4bba1_level0_row0" class="row_heading level0 row0" >MLPRegressor</th>
#       <td id="T_4bba1_row0_col0" class="data row0 col0" >1.9120</td>
#       <td id="T_4bba1_row0_col1" class="data row0 col1" >8.0533</td>
#       <td id="T_4bba1_row0_col2" class="data row0 col2" >2.8378</td>
#       <td id="T_4bba1_row0_col3" class="data row0 col3" >0.8422</td>
#       <td id="T_4bba1_row0_col4" class="data row0 col4" >8.2820</td>
#     </tr>
#     <tr>
#       <th id="T_4bba1_level0_row1" class="row_heading level0 row1" >RandomForest</th>
#       <td id="T_4bba1_row1_col0" class="data row1 col0" >1.6741</td>
#       <td id="T_4bba1_row1_col1" class="data row1 col1" >5.6382</td>
#       <td id="T_4bba1_row1_col2" class="data row1 col2" >2.3745</td>
#       <td id="T_4bba1_row1_col3" class="data row1 col3" >0.8895</td>
#       <td id="T_4bba1_row1_col4" class="data row1 col4" >7.6276</td>
#     </tr>
#     <tr>
#       <th id="T_4bba1_level0_row2" class="row_heading level0 row2" >SVR</th>
#       <td id="T_4bba1_row2_col0" class="data row2 col0" >1.7669</td>
#       <td id="T_4bba1_row2_col1" class="data row2 col1" >5.9679</td>
#       <td id="T_4bba1_row2_col2" class="data row2 col2" >2.4429</td>
#       <td id="T_4bba1_row2_col3" class="data row2 col3" >0.8831</td>
#       <td id="T_4bba1_row2_col4" class="data row2 col4" >7.6962</td>
#     </tr>
#     <tr>
#       <th id="T_4bba1_level0_row3" class="row_heading level0 row3" >KNeighbors</th>
#       <td id="T_4bba1_row3_col0" class="data row3 col0" >1.9459</td>
#       <td id="T_4bba1_row3_col1" class="data row3 col1" >6.7440</td>
#       <td id="T_4bba1_row3_col2" class="data row3 col2" >2.5969</td>
#       <td id="T_4bba1_row3_col3" class="data row3 col3" >0.8679</td>
#       <td id="T_4bba1_row3_col4" class="data row3 col4" >8.6969</td>
#     </tr>
#     <tr>
#       <th id="T_4bba1_level0_row4" class="row_heading level0 row4" >TensorFlow_DNN</th>
#       <td id="T_4bba1_row4_col0" class="data row4 col0" >1.8800</td>
#       <td id="T_4bba1_row4_col1" class="data row4 col1" >6.6483</td>
#       <td id="T_4bba1_row4_col2" class="data row4 col2" >2.5784</td>
#       <td id="T_4bba1_row4_col3" class="data row4 col3" >0.8697</td>
#       <td id="T_4bba1_row4_col4" class="data row4 col4" >8.3662</td>
#     </tr>
#   </tbody>
# </table>
# Ranking (R2):
#   1. RandomForest: R2 = 0.8895
#   2. SVR: R2 = 0.8831
#   3. TensorFlow_DNN: R2 = 0.8697
#   4. KNeighbors: R2 = 0.8679
#   5. MLPRegressor: R2 = 0.8422

# %% [markdown]
# ## 11. Wykresy porownawcze

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

metrics_to_plot = ['MAE', 'RMSE', 'R2', 'MAPE']
titles = ['MAE', 'RMSE', 'R2', 'MAPE (%)']

for idx, (metric, title) in enumerate(zip(metrics_to_plot, titles)):
    ax = axes[idx // 2, idx % 2]
    colors = sns.color_palette('husl', len(results))
    bars = ax.bar(results_df.index, results_df[metric], color=colors)
    ax.set_title(title, fontweight='bold')
    ax.set_ylabel(metric)
    ax.tick_params(axis='x', rotation=45)

    for bar, val in zip(bars, results_df[metric]):
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height(),
                f'{val:.3f}', ha='center', va='bottom', fontsize=9)

plt.suptitle('Porownanie modeli regresyjnych', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
axes = axes.flatten()

for idx, (model_name, y_pred) in enumerate(predictions.items()):
    ax = axes[idx]
    ax.scatter(y_test, y_pred, alpha=0.6, edgecolors='k', linewidth=0.5)
    ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()],
            'r--', linewidth=2, label='Idealne dopasowanie')
    ax.set_xlabel('Rzeczywiste (MPG)')
    ax.set_ylabel('Przewidywane (MPG)')
    ax.set_title(f'{model_name}\nR2 = {results[model_name]["R2"]:.4f}')
    ax.legend()
    ax.grid(True, alpha=0.3)

axes[-1].axis('off')

plt.suptitle('Wartosci rzeczywiste vs przewidywane', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 12. Bledy wzgledne

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

for idx, (model_name, y_pred) in enumerate(predictions.items()):
    ax = axes[idx]
    errors = np.abs((y_test - y_pred) / y_test) * 100
    ax.hist(errors, bins=20, edgecolor='black', alpha=0.7)
    ax.axvline(np.mean(errors), color='red', linestyle='--',
               label=f'Srednia: {np.mean(errors):.2f}%')
    ax.axvline(np.median(errors), color='green', linestyle='--',
               label=f'Mediana: {np.median(errors):.2f}%')
    ax.set_xlabel('Blad wzgledny (%)')
    ax.set_ylabel('Liczebnosc')
    ax.set_title(f'{model_name}')
    ax.legend()
    ax.grid(True, alpha=0.3)

axes[-1].axis('off')

plt.suptitle('Rozklad bledow wzglednych (MAPE)', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

print('\nStatystyki bledow wzglednych (%):')
error_stats = pd.DataFrame()
for model_name, y_pred in predictions.items():
    errors = np.abs((y_test - y_pred) / y_test) * 100
    error_stats[model_name] = errors

display(error_stats.describe().round(2))
# Out:
# Statystyki bledow wzglednych (%):
#        MLPRegressor  RandomForest    SVR  KNeighbors  TensorFlow_DNN
# count         79.00         79.00  79.00       79.00           79.00
# mean           8.28          7.63   7.70        8.70            8.37
# std            9.78          8.25   7.34        7.76            7.87
# min            0.22          0.17   0.17        0.02            0.06
# 25%            2.57          2.28   2.82        3.00            2.50
# 50%            4.58          5.25   5.09        6.78            6.74
# 75%           11.60          9.46  11.28       11.63           11.66
# max           66.69         50.75  38.35       36.51           38.65

# %% [markdown]
# ## 13. Dokladnosc w zaleznosci od typu samochodu

# %%
car_types = ['amerykanski', 'europejski', 'japonski']
type_results = {ct: {} for ct in car_types}

for model_name, y_pred in predictions.items():
    for car_type in car_types:
        mask = car_type_test == car_type
        if mask.sum() > 0:
            metrics = calculate_metrics(y_test[mask], y_pred[mask])
            type_results[car_type][model_name] = metrics

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for idx, car_type in enumerate(car_types):
    ax = axes[idx]
    model_names = list(type_results[car_type].keys())
    mape_values = [type_results[car_type][m]['MAPE'] for m in model_names]
    r2_values = [type_results[car_type][m]['R2'] for m in model_names]

    x = np.arange(len(model_names))
    width = 0.35

    bars1 = ax.bar(x - width/2, mape_values, width, label='MAPE (%)', color='steelblue')
    ax2 = ax.twinx()
    bars2 = ax2.bar(x + width/2, r2_values, width, label='R2', color='coral')

    ax.set_xlabel('Model')
    ax.set_ylabel('MAPE (%)')
    ax2.set_ylabel('R2')
    ax.set_title(f'{car_type.capitalize()}', fontweight='bold')
    ax.set_xticks(x)
    ax.set_xticklabels([m.replace('_', '\n') for m in model_names], fontsize=8)

    lines1, labels1 = ax.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax.legend(lines1 + lines2, labels1 + labels2, loc='upper left')

plt.suptitle('Dokladnosc wg typu samochodu', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

print('\nWyniki wedlug typu:')
for car_type in car_types:
    print(f'\n--- {car_type.upper()} ---')
    type_df = pd.DataFrame(type_results[car_type]).T
    display(type_df[['MAE', 'R2', 'MAPE']].round(3))
# Out:
# Wyniki wedlug typu:
#
# --- AMERYKANSKI ---
#                   MAE     R2   MAPE
# MLPRegressor    1.363  0.839  6.726
# RandomForest    1.442  0.839  7.583
# SVR             1.418  0.852  7.231
# KNeighbors      1.580  0.823  8.042
# TensorFlow_DNN  1.492  0.829  7.494
# --- EUROPEJSKI ---
#                   MAE     R2   MAPE
# MLPRegressor    2.669  0.732  9.975
# RandomForest    2.016  0.840  7.630
# SVR             1.937  0.827  6.829
# KNeighbors      2.130  0.821  8.344
# TensorFlow_DNN  1.909  0.847  7.432
# --- JAPONSKI ---
#                   MAE     R2    MAPE
# MLPRegressor    1.584  0.839   6.123
# RandomForest    1.292  0.895   4.734
# SVR             1.898  0.818   7.375
# KNeighbors      2.702  0.632  10.420
# TensorFlow_DNN  2.399  0.703   9.604

# %% [markdown]
# ## 14. Podsumowanie

# %%
print('PODSUMOWANIE')

final_results = results_df.copy()
final_results['Ranking'] = final_results['R2'].rank(ascending=False).astype(int)
final_results = final_results.sort_values('Ranking')

display(final_results.style.format({
    'MAE': '{:.4f}',
    'MSE': '{:.4f}',
    'RMSE': '{:.4f}',
    'R2': '{:.4f}',
    'MAPE': '{:.2f}%'
}).highlight_min(subset=['MAE', 'MSE', 'RMSE', 'MAPE'], color='lightgreen')
 .highlight_max(subset=['R2'], color='lightgreen'))

best_model = final_results.index[0]
print(f'\nNajlepszy model: {best_model}')
print(f'  R2 = {final_results.loc[best_model, "R2"]:.4f}')
print(f'  MAE = {final_results.loc[best_model, "MAE"]:.4f} MPG')
print(f'  MAPE = {final_results.loc[best_model, "MAPE"]:.2f}%')
# Out:
# PODSUMOWANIE
# <style type="text/css">
# #T_ef1b4_row0_col0, #T_ef1b4_row0_col1, #T_ef1b4_row0_col2, #T_ef1b4_row0_col3, #T_ef1b4_row0_col4 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ef1b4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef1b4_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_ef1b4_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_ef1b4_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_ef1b4_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_ef1b4_level0_col4" class="col_heading level0 col4" >MAPE</th>
#       <th id="T_ef1b4_level0_col5" class="col_heading level0 col5" >Ranking</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef1b4_level0_row0" class="row_heading level0 row0" >RandomForest</th>
#       <td id="T_ef1b4_row0_col0" class="data row0 col0" >1.6741</td>
#       <td id="T_ef1b4_row0_col1" class="data row0 col1" >5.6382</td>
#       <td id="T_ef1b4_row0_col2" class="data row0 col2" >2.3745</td>
#       <td id="T_ef1b4_row0_col3" class="data row0 col3" >0.8895</td>
#       <td id="T_ef1b4_row0_col4" class="data row0 col4" >7.63%</td>
#       <td id="T_ef1b4_row0_col5" class="data row0 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ef1b4_level0_row1" class="row_heading level0 row1" >SVR</th>
#       <td id="T_ef1b4_row1_col0" class="data row1 col0" >1.7669</td>
#       <td id="T_ef1b4_row1_col1" class="data row1 col1" >5.9679</td>
#       <td id="T_ef1b4_row1_col2" class="data row1 col2" >2.4429</td>
#       <td id="T_ef1b4_row1_col3" class="data row1 col3" >0.8831</td>
#       <td id="T_ef1b4_row1_col4" class="data row1 col4" >7.70%</td>
#       <td id="T_ef1b4_row1_col5" class="data row1 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ef1b4_level0_row2" class="row_heading level0 row2" >TensorFlow_DNN</th>
#       <td id="T_ef1b4_row2_col0" class="data row2 col0" >1.8800</td>
#       <td id="T_ef1b4_row2_col1" class="data row2 col1" >6.6483</td>
#       <td id="T_ef1b4_row2_col2" class="data row2 col2" >2.5784</td>
#       <td id="T_ef1b4_row2_col3" class="data row2 col3" >0.8697</td>
#       <td id="T_ef1b4_row2_col4" class="data row2 col4" >8.37%</td>
#       <td id="T_ef1b4_row2_col5" class="data row2 col5" >3</td>
#     </tr>
#     <tr>
#       <th id="T_ef1b4_level0_row3" class="row_heading level0 row3" >KNeighbors</th>
#       <td id="T_ef1b4_row3_col0" class="data row3 col0" >1.9459</td>
#       <td id="T_ef1b4_row3_col1" class="data row3 col1" >6.7440</td>
#       <td id="T_ef1b4_row3_col2" class="data row3 col2" >2.5969</td>
#       <td id="T_ef1b4_row3_col3" class="data row3 col3" >0.8679</td>
#       <td id="T_ef1b4_row3_col4" class="data row3 col4" >8.70%</td>
#       <td id="T_ef1b4_row3_col5" class="data row3 col5" >4</td>
#     </tr>
#     <tr>
#       <th id="T_ef1b4_level0_row4" class="row_heading level0 row4" >MLPRegressor</th>
#       <td id="T_ef1b4_row4_col0" class="data row4 col0" >1.9120</td>
#       <td id="T_ef1b4_row4_col1" class="data row4 col1" >8.0533</td>
#       <td id="T_ef1b4_row4_col2" class="data row4 col2" >2.8378</td>
#       <td id="T_ef1b4_row4_col3" class="data row4 col3" >0.8422</td>
#       <td id="T_ef1b4_row4_col4" class="data row4 col4" >8.28%</td>
#       <td id="T_ef1b4_row4_col5" class="data row4 col5" >5</td>
#     </tr>
#   </tbody>
# </table>
# Najlepszy model: RandomForest
#   R2 = 0.8895
#   MAE = 1.6741 MPG
#   MAPE = 7.63%
